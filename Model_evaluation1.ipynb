# %%
from sklearn.metrics import r2_score, mean_absolute_error, mean_squared_error
import numpy as np
import pandas as pd

results = []

def evaluate(name, y_true, y_pred):
    results.append({
            "Model": name,
                    "R2": r2_score(y_true, y_pred),
                            "MAE": mean_absolute_error(y_true, y_pred),
                                    "RMSE": np.sqrt(mean_squared_error(y_true, y_pred))
                                        })

                              # Model 1
                                        pred1 = model1.predict(X1_test)
                                        evaluate("Baseline Linear", y1_test, pred1)

                                        # Model 2
                                        pred2 = model2.predict(X2_test)
                                        evaluate("Smoothed Linear", y2_test, pred2)

                                        # Model 3
                                        pred3 = model3.predict(X3_test)
                                        evaluate("Lag Linear", y3_test, pred3)

                                        # Model 4 (FIXED)
                                        evaluate("Lasso", y_test_lasso, pred_lasso)

                                        # Model 5 (FIXED)
                                        evaluate("Polynomial Ridge", y_test_poly, pred_poly)

                                        results_df = pd.DataFrame(results)

                                        print(results_df.sort_values("R2", ascending=False))

# %%
from sklearn.metrics import r2_score, mean_absolute_error, mean_squared_error
import numpy as np

r2 = r2_score(y3_test, pred3)
mae = mean_absolute_error(y3_test, pred3)
mse = mean_squared_error(y3_test, pred3)
rmse = np.sqrt(mse)

print("FINAL MODEL: Lag Linear Regression")
print("R2 Score :", r2)
print("MAE      :", mae)
print("MSE      :", mse)
print("RMSE     :", rmse)
